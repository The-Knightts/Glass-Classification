# %%
import pandas as pd  
import pickle

# %%
dataset = pd.read_csv("C:\\Users\\KUBER\\OneDrive\\Documents\\Team Losser\\CSV\\glass.csv")

# %%
dataset.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>RI</th>
#       <th>Na</th>
#       <th>Mg</th>
#       <th>Al</th>
#       <th>Si</th>
#       <th>K</th>
#       <th>Ca</th>
#       <th>Ba</th>
#       <th>Fe</th>
#       <th>Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.52101</td>
#       <td>13.64</td>
#       <td>4.49</td>
#       <td>1.10</td>
#       <td>71.78</td>
#       <td>0.06</td>
#       <td>8.75</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.51761</td>
#       <td>13.89</td>
#       <td>3.60</td>
#       <td>1.36</td>
# ...

# %%
dataset.tail()
# Out:
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
dataset.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
dataset.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
elements = ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe']

# %%
dataset.nunique()
# Out:
# RI      178
# Na      142
# Mg       94
# Al      118
# Si      133
# K        65
# Ca      143
# Ba       34
# Fe       32
# Type      6
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
for i in dataset[elements].columns:
    plt.figure(figsize = (10, 6))
    plt.hist(dataset[elements][i], bins = 50)
    plt.title("Histogram OF Elements")
    plt.xticks(rotation = 0)
    plt.grid(True)
    plt.xlabel(i)
    plt.ylabel('Range')
    plt.show()

# %%
for i in elements:
    value_counts = dataset[i].value_counts()

    top_values = value_counts.head(10)
    plt.figure(figsize = (10, 6))
    plt.bar([str(x) for x in top_values.index],top_values)
    plt.xlabel(i)
    plt.ylabel('Counts')
    plt.title(f'Bar Plot of {i}')
    plt.xticks(rotation = 45)
    plt.show()

# %%
average_weights = dataset[elements].mean()

plt.figure(figsize = (10, 6))
plt.pie(average_weights, labels = elements, autopct = '%1.1f%%', startangle = 140)
plt.title('Average Percentage Weight of Elements in Glass Samples')
plt.show()

# %%
dataset.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
plt.figure(figsize = (15, 10))

plt.boxplot(dataset[elements])
plt.title('Box Plot of Chemical Elements and Refractive Index in Glass Samples')
plt.xlabel('Element')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

for element in elements:
    plt.scatter(dataset.index, dataset[element], label=element)

plt.title('Scatter Plot of Elements')
plt.xlabel('Index')
plt.ylabel('Element Values')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

for element in elements:
    plt.plot(dataset.index, dataset[element], label=element)

plt.title('Line Plot of Elements')
plt.xlabel('Index')
plt.ylabel('Element Values')
plt.legend()
plt.grid(True)
plt.show()

# %%
model = pickle.load(open('clf.pkl','rb'))

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import accuracy_score          
from sklearn.model_selection import train_test_split

# %%
x = dataset.drop(columns = ['Type'])
y = dataset['Type']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2, random_state = 1)

# %%
clf = RandomForestClassifier(n_estimators = 100, random_state = 42)

# %%
print(x)
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
print(y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 214, dtype: int64

# %%
clf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(random_state=42)

# %%
xtrain.count()
# Out:
# RI    171
# Na    171
# Mg    171
# Al    171
# Si    171
# K     171
# Ca    171
# Ba    171
# Fe    171
# dtype: int64

# %%
ytrain.count()
# Out:
# 171

# %%
ypred = clf.predict(xtest)

# %%
ypred
# Out:
# array([6, 7, 2, 2, 1, 1, 1, 1, 1, 1, 2, 1, 2, 1, 1, 2, 2, 1, 1, 1, 1, 7,
#        2, 1, 2, 3, 2, 2, 2, 1, 5, 6, 1, 1, 1, 2, 2, 3, 2, 2, 1, 7, 7],
#       dtype=int64)

# %%
accuracy = accuracy_score(ytest, ypred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.74

# %%
def predict_glass_type(clf, new_data):
   
    new_df = pd.DataFrame(new_data)

    predicted_labels = clf.predict(new_df)
    
    glass_names = {
        1: "building_windows_float_processed",
        2: "building_windows_non_float_processed",
        3: "vehicle_windows_float_processed",
        4: "vehicle_windows_non_float_processed",
        5: "containers",
        6: "tableware",
        7: "headlamps"
    }
    
    predicted_label = predicted_labels[0]
    predicted_name = glass_names.get(predicted_label, "Unknown class")
    
    return predicted_label, predicted_name

new_data = {
    'RI': [1.52],
    'Na': [13.64],
    'Mg': [4.49],
    'Al': [1.10],
    'Si': [71.78],
    'K':  [0.06],
    'Ca': [8.75],
    'Ba': [0.0],
    'Fe': [0.0]
}

predicted_label, predicted_name = predict_glass_type(clf, new_data)
print(f'Predicted Glass Type (Label): {predicted_label}')
print(f'Predicted Glass Type (Name): {predicted_name}')
# Out:
# Predicted Glass Type (Label): 2
# Predicted Glass Type (Name): building_windows_non_float_processed

# %%
new_data = {
    'RI': [1.51617],
    'Na': [14.95],
    'Mg': [0.0],
    'Al': [2.27],
    'Si': [73.30],
    'K':  [0.00],
    'Ca': [8.71],
    'Ba': [0.67	],
    'Fe': [0.0]
}

predicted_label, predicted_name = predict_glass_type(clf, new_data)
print(f'Predicted Glass Type (Label): {predicted_label}')
print(f'Predicted Glass Type (Name): {predicted_name}')
# Out:
# Predicted Glass Type (Label): 7
# Predicted Glass Type (Name): headlamps

# %%
import random
random_row = dataset.sample(n=1).squeeze()

new_data = {
    'RI': [random.choice(dataset['RI'])],
    'Na': [random.choice(dataset['Na'])],
    'Mg': [random.choice(dataset['Mg'])],
    'Al': [random.choice(dataset['Al'])],
    'Si': [random.choice(dataset['Si'])],
    'K':  [random.choice(dataset['K'])],
    'Ca': [random.choice(dataset['Ca'])],
    'Ba': [random.choice(dataset['Ba'])],
    'Fe': [random.choice(dataset['Fe'])]
}

predicted_label, predicted_name = predict_glass_type(clf, new_data)
print(f'Predicted Glass Type (Label): {predicted_label}')
print(f'Predicted Glass Type (Name): {predicted_name}')
# Out:
# Predicted Glass Type (Label): 2
# Predicted Glass Type (Name): building_windows_non_float_processed

# %%
pickle.dump(clf,open('clf.pkl','wb'))
